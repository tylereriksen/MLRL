# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import numpy as np
import gymnasium as gym
import gym_anytrading
from collections import deque
import matplotlib.pyplot as plt
import pandas as pd
import torch.optim as optim

# %%
class ActorCritic(nn.Module):
    def __init__(self, input_dim, n_actions):
        super(ActorCritic, self).__init__()
        self.actor = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, n_actions),
            nn.Softmax(dim=-1)
        )
        
        self.critic = nn.Sequential(
            nn.Linear(input_dim, 128),
            nn.ReLU(),
            nn.Linear(128, 1)
        )
        
    def forward(self, state):
        probs = self.actor(state)
        value = self.critic(state)
        return probs, value
    
    
def compute_loss(log_probs, values, rewards, gamma):
    # Compute returns and advantage
    returns = []
    Gt = 0
    pw = 0
    for reward in reversed(rewards):
        Gt = reward + gamma ** pw * Gt
        returns.insert(0, Gt)
        pw += 1
    
    log_probs = torch.stack(log_probs)
    returns = torch.tensor(returns)
    values = torch.cat(values)
    
    advantage = returns - values
    actor_loss = -(log_probs * advantage).mean()
    critic_loss = advantage.pow(2).mean()
    
    return actor_loss, critic_loss

# %%
def train(env, model, episode, T, actor_lr=0.01, critic_lr=0.05, gamma=0.99):
    state, _ = env.reset()
    
    
    log_probs = []
    values = []
    rewards = []
    episode_reward = 0

    for t in range(T):
        state = state.flatten()
        state = torch.tensor([state], dtype=torch.float32)
        
        probs, value = model(state)
        distribution = torch.distributions.Categorical(probs)
        action = distribution.sample()
        next_state, reward, terminated, truncated, info = env.step(action.item())
        done = terminated or truncated
        
        log_prob = distribution.log_prob(action)
        log_probs.append(log_prob)
        values.append(value)
        rewards.append(reward)
        episode_reward += reward
        if done:
            #print(f"Episode {episode} finished with total reward {episode_reward}")
            break
        state = next_state
    actor_loss, critic_loss = compute_loss(log_probs, values, rewards, gamma)
    
    for param in model.actor.parameters():
        if param.grad is not None:
            param.grad.data.zero_()
    actor_loss.backward(retain_graph=True)
    
    for param in model.actor.parameters():
        param.data -= actor_lr * param.grad.data
        
    
    for param in model.critic.parameters():
        if param.grad is not None:
            param.grad.data.zero_()
    critic_loss.backward()
    for param in model.critic.parameters():
        param.data -= critic_lr * param.grad.data
    
    return episode_reward, info

# %%
env = gym.make('forex-v0', frame_bound=(10, 500), window_size=10)
input_dim = env.observation_space.shape[1] * env.observation_space.shape[0]
n_actions = env.action_space.n

model = ActorCritic(input_dim, n_actions)
optimizer = optim.Adam(model.parameters(), lr=0.001)
T = env.frame_bound[1] - env.frame_bound[0]

num_episodes = 300
for episode in range(num_episodes):
    reward, info = train(env, model, episode, T)
    print(f"Episode: {episode+1}, Reward: {reward}")
    print("info: ", info)
    print()
# Out:
# /Users/ryankan/anaconda3/lib/python3.11/site-packages/gymnasium/core.py:297: UserWarning: WARN: env.frame_bound to get variables from other wrappers is deprecated and will be removed in v1.0, to get this variable you can do `env.unwrapped.frame_bound` for environment variables or `env.get_attr('frame_bound')` that will search the reminding wrappers.
#   logger.warn(
# /var/folders/jv/c7kjn4v159b6c6q5vxtjnp_w0000gn/T/ipykernel_36361/1841575082.py:12: UserWarning: Creating a tensor from a list of numpy.ndarrays is extremely slow. Please consider converting the list to a single numpy.ndarray with numpy.array() before converting to a tensor. (Triggered internally at /Users/runner/work/pytorch/pytorch/pytorch/torch/csrc/utils/tensor_new.cpp:248.)
#   state = torch.tensor([state], dtype=torch.float32)
# Episode: 1, Reward: 274.09911155700684
# info:  {'total_reward': 274.09911155700684, 'total_profit': 0.9732487103798101, 'position': <Positions.Long: 1>}
#
# Episode: 2, Reward: 109.48061943054199
# info:  {'total_reward': 109.48061943054199, 'total_profit': 0.9634638999985708, 'position': <Positions.Short: 0>}
#
# Episode: 3, Reward: -464.91026878356934
# info:  {'total_reward': -464.91026878356934, 'total_profit': 0.9383310757435527, 'position': <Positions.Long: 1>}
#
# Episode: 4, Reward: -439.9096965789795
# info:  {'total_reward': -439.9096965789795, 'total_profit': 0.9411874808597205, 'position': <Positions.Short: 0>}
#
# Episode: 5, Reward: 351.5148162841797
# info:  {'total_reward': 351.5148162841797, 'total_profit': 0.9752010745711761, 'position': <Positions.Short: 0>}
#
# Episode: 6, Reward: -300.49800872802734
# info:  {'total_reward': -300.49800872802734, 'total_profit': 0.9466241312930493, 'position': <Positions.Long: 1>}
#
# Episode: 7, Reward: -18.918514251708984
# info:  {'total_reward': -18.918514251708984, 'total_profit': 0.9612140827247105, 'position': <Positions.Short: 0>}
#
# Episode: 8, Reward: -16.106367111206055
# info:  {'total_reward': -16.106367111206055, 'total_profit': 0.9586808911207247, 'position': <Positions.Long: 1>}
#
# Episode: 9, Reward: -54.48460578918457
# info:  {'total_reward': -54.48460578918457, 'total_profit': 0.9548362187095532, 'position': <Positions.Short: 0>}
#
# Episode: 10, Reward: 335.29162406921387
# info:  {'total_reward': 335.29162406921387, 'total_profit': 0.9734661374848624, 'position': <Positions.Long: 1>}
#
# Episode: 11, Reward: -121.70672416687012
# info:  {'total_reward': -121.70672416687012, 'total_profit': 0.9522647188719553, 'position': <Positions.Long: 1>}
#
# Episode: 12, Reward: -357.18798637390137
# info:  {'total_reward': -357.18798637390137, 'total_profit': 0.9391221505996852, 'position': <Positions.Short: 0>}
#
# Episode: 13, Reward: 79.68306541442871
# info:  {'total_reward': 79.68306541442871, 'total_profit': 0.9627026569740939, 'position': <Positions.Short: 0>}
#
# Episode: 14, Reward: 88.11473846435547
# info:  {'total_reward': 88.11473846435547, 'total_profit': 0.9675149948436016, 'position': <Positions.Long: 1>}
#
# Episode: 15, Reward: 367.51747131347656
# info:  {'total_reward': 367.51747131347656, 'total_profit': 0.9760348213104021, 'position': <Positions.Long: 1>}
#
# Episode: 16, Reward: -307.389497756958
# info:  {'total_reward': -307.389497756958, 'total_profit': 0.9425125375798219, 'position': <Positions.Short: 0>}
#
# Episode: 17, Reward: 197.5107192993164
# info:  {'total_reward': 197.5107192993164, 'total_profit': 0.9671034650174684, 'position': <Positions.Long: 1>}
#
# Episode: 18, Reward: 59.28635597229004
# info:  {'total_reward': 59.28635597229004, 'total_profit': 0.9598580496000881, 'position': <Positions.Short: 0>}
#
# Episode: 19, Reward: 71.48504257202148
# info:  {'total_reward': 71.48504257202148, 'total_profit': 0.9608590365868751, 'position': <Positions.Short: 0>}
#
# Episode: 20, Reward: 18.6920166015625
# info:  {'total_reward': 18.6920166015625, 'total_profit': 0.9592895121927447, 'position': <Positions.Short: 0>}
#
# Episode: 21, Reward: -207.9010009765625
# info:  {'total_reward': -207.9010009765625, 'total_profit': 0.9505940120516995, 'position': <Positions.Short: 0>}
#
# Episode: 22, Reward: -159.29937362670898
# info:  {'total_reward': -159.29937362670898, 'total_profit': 0.9496987964710675, 'position': <Positions.Long: 1>}
#
# Episode: 23, Reward: 229.0964126586914
# info:  {'total_reward': 229.0964126586914, 'total_profit': 0.9684682352704936, 'position': <Positions.Short: 0>}
#
# Episode: 24, Reward: 153.7168025970459
# info:  {'total_reward': 153.7168025970459, 'total_profit': 0.964838192284778, 'position': <Positions.Short: 0>}
#
# Episode: 25, Reward: 85.90459823608398
# info:  {'total_reward': 85.90459823608398, 'total_profit': 0.9638750150649235, 'position': <Positions.Short: 0>}
#
# Episode: 26, Reward: -44.498443603515625
# info:  {'total_reward': -44.498443603515625, 'total_profit': 0.9572220505374921, 'position': <Positions.Long: 1>}
#
# Episode: 27, Reward: 192.71016120910645
# info:  {'total_reward': 192.71016120910645, 'total_profit': 0.9665090985959452, 'position': <Positions.Short: 0>}
#
# Episode: 28, Reward: -375.1063346862793
# info:  {'total_reward': -375.1063346862793, 'total_profit': 0.9403654820448502, 'position': <Positions.Short: 0>}
#
# Episode: 29, Reward: -18.284320831298828
# info:  {'total_reward': -18.284320831298828, 'total_profit': 0.9578013476198589, 'position': <Positions.Short: 0>}
#
# Episode: 30, Reward: 206.27975463867188
# info:  {'total_reward': 206.27975463867188, 'total_profit': 0.9692850459798995, 'position': <Positions.Short: 0>}
#
# Episode: 31, Reward: 725.5148887634277
# info:  {'total_reward': 725.5148887634277, 'total_profit': 0.992091421263123, 'position': <Positions.Short: 0>}
#
# Episode: 32, Reward: 634.0861320495605
# info:  {'total_reward': 634.0861320495605, 'total_profit': 0.9861669018454277, 'position': <Positions.Long: 1>}
#
# Episode: 33, Reward: 403.5162925720215
# info:  {'total_reward': 403.5162925720215, 'total_profit': 0.9795557207552729, 'position': <Positions.Short: 0>}
#
# Episode: 34, Reward: 151.89766883850098
# info:  {'total_reward': 151.89766883850098, 'total_profit': 0.9659981894972834, 'position': <Positions.Long: 1>}
#
# Episode: 35, Reward: 7.102489471435547
# info:  {'total_reward': 7.102489471435547, 'total_profit': 0.9593667710710309, 'position': <Positions.Long: 1>}
#
# Episode: 36, Reward: 389.3089294433594
# info:  {'total_reward': 389.3089294433594, 'total_profit': 0.9784754639856417, 'position': <Positions.Short: 0>}
#
# Episode: 37, Reward: 597.0883369445801
# info:  {'total_reward': 597.0883369445801, 'total_profit': 0.9878472863702472, 'position': <Positions.Long: 1>}
#
# Episode: 38, Reward: -257.9188346862793
# info:  {'total_reward': -257.9188346862793, 'total_profit': 0.946929201539536, 'position': <Positions.Long: 1>}
#
# Episode: 39, Reward: 135.47778129577637
# info:  {'total_reward': 135.47778129577637, 'total_profit': 0.9655780870585317, 'position': <Positions.Long: 1>}
#
# Episode: 40, Reward: -17.48800277709961
# info:  {'total_reward': -17.48800277709961, 'total_profit': 0.9593556987218578, 'position': <Positions.Short: 0>}
#
# Episode: 41, Reward: 280.2908420562744
# info:  {'total_reward': 280.2908420562744, 'total_profit': 0.967635963732077, 'position': <Positions.Short: 0>}
#
# Episode: 42, Reward: 25.315284729003906
# info:  {'total_reward': 25.315284729003906, 'total_profit': 0.9615651918690007, 'position': <Positions.Short: 0>}
#
# Episode: 43, Reward: 674.7055053710938
# info:  {'total_reward': 674.7055053710938, 'total_profit': 0.9894353635515555, 'position': <Positions.Long: 1>}
#
# Episode: 44, Reward: -685.0779056549072
# info:  {'total_reward': -685.0779056549072, 'total_profit': 0.9279196381239262, 'position': <Positions.Short: 0>}
#
# Episode: 45, Reward: 42.09160804748535
# info:  {'total_reward': 42.09160804748535, 'total_profit': 0.9627358921831831, 'position': <Positions.Long: 1>}
#
# Episode: 46, Reward: 223.10972213745117
# info:  {'total_reward': 223.10972213745117, 'total_profit': 0.9681790000630552, 'position': <Positions.Long: 1>}
#
# Episode: 47, Reward: -378.29041481018066
# info:  {'total_reward': -378.29041481018066, 'total_profit': 0.9442588542511364, 'position': <Positions.Long: 1>}
#
# Episode: 48, Reward: -311.1076354980469
# info:  {'total_reward': -311.1076354980469, 'total_profit': 0.9431713018618768, 'position': <Positions.Long: 1>}
#
# Episode: 49, Reward: -183.67767333984375
# info:  {'total_reward': -183.67767333984375, 'total_profit': 0.9543500320287942, 'position': <Positions.Short: 0>}
#
# Episode: 50, Reward: 556.1017990112305
# info:  {'total_reward': 556.1017990112305, 'total_profit': 0.9862066354399195, 'position': <Positions.Short: 0>}
#
# Episode: 51, Reward: -124.70722198486328
# info:  {'total_reward': -124.70722198486328, 'total_profit': 0.9537826171975708, 'position': <Positions.Long: 1>}
#
# Episode: 52, Reward: 322.30496406555176
# info:  {'total_reward': 322.30496406555176, 'total_profit': 0.9714466342178993, 'position': <Positions.Long: 1>}
#
# Episode: 53, Reward: 436.5050792694092
# info:  {'total_reward': 436.5050792694092, 'total_profit': 0.9788331327256983, 'position': <Positions.Long: 1>}
#
# Episode: 54, Reward: -190.1078224182129
# info:  {'total_reward': -190.1078224182129, 'total_profit': 0.9490229420125816, 'position': <Positions.Short: 0>}
# Episode: 55, Reward: -290.50350189208984
# info:  {'total_reward': -290.50350189208984, 'total_profit': 0.9488097327349099, 'position': <Positions.Long: 1>}
#
# Episode: 56, Reward: -224.1194248199463
# info:  {'total_reward': -224.1194248199463, 'total_profit': 0.9492979246188287, 'position': <Positions.Short: 0>}
#
# Episode: 57, Reward: -2.6917457580566406
# info:  {'total_reward': -2.6917457580566406, 'total_profit': 0.9598276065555743, 'position': <Positions.Short: 0>}
#
# Episode: 58, Reward: 183.29977989196777
# info:  {'total_reward': 183.29977989196777, 'total_profit': 0.9683023625003251, 'position': <Positions.Short: 0>}
#
# Episode: 59, Reward: 337.0988368988037
# info:  {'total_reward': 337.0988368988037, 'total_profit': 0.9743498378023, 'position': <Positions.Short: 0>}
#
# Episode: 60, Reward: -616.985559463501
# info:  {'total_reward': -616.985559463501, 'total_profit': 0.9298250679113595, 'position': <Positions.Short: 0>}
#
# Episode: 61, Reward: -115.08822441101074
# info:  {'total_reward': -115.08822441101074, 'total_profit': 0.9506430250919712, 'position': <Positions.Short: 0>}
#
# Episode: 62, Reward: 349.29871559143066
# info:  {'total_reward': 349.29871559143066, 'total_profit': 0.9727262830796194, 'position': <Positions.Long: 1>}
#
# Episode: 63, Reward: 228.89375686645508
# info:  {'total_reward': 228.89375686645508, 'total_profit': 0.9681644612570244, 'position': <Positions.Short: 0>}
#
# Episode: 64, Reward: -376.88255310058594
# info:  {'total_reward': -376.88255310058594, 'total_profit': 0.9438737018686788, 'position': <Positions.Short: 0>}
#
# Episode: 65, Reward: -182.28888511657715
# info:  {'total_reward': -182.28888511657715, 'total_profit': 0.9486601842607733, 'position': <Positions.Short: 0>}
#
# Episode: 66, Reward: -337.10241317749023
# info:  {'total_reward': -337.10241317749023, 'total_profit': 0.9450576239055717, 'position': <Positions.Long: 1>}
#
# Episode: 67, Reward: 257.8866481781006
# info:  {'total_reward': 257.8866481781006, 'total_profit': 0.966844365433486, 'position': <Positions.Short: 0>}
#
# Episode: 68, Reward: -66.90144538879395
# info:  {'total_reward': -66.90144538879395, 'total_profit': 0.9568978134458225, 'position': <Positions.Long: 1>}
#
# Episode: 69, Reward: 33.29753875732422
# info:  {'total_reward': 33.29753875732422, 'total_profit': 0.9615190163419236, 'position': <Positions.Short: 0>}
#
# Episode: 70, Reward: -391.31760597229004
# info:  {'total_reward': -391.31760597229004, 'total_profit': 0.9438141204493612, 'position': <Positions.Long: 1>}
#
# Episode: 71, Reward: 494.3084716796875
# info:  {'total_reward': 494.3084716796875, 'total_profit': 0.9821242693992749, 'position': <Positions.Long: 1>}
#
# Episode: 72, Reward: -98.48833084106445
# info:  {'total_reward': -98.48833084106445, 'total_profit': 0.9576871278331849, 'position': <Positions.Long: 1>}
#
# Episode: 73, Reward: -181.3066005706787
# info:  {'total_reward': -181.3066005706787, 'total_profit': 0.950554386576661, 'position': <Positions.Short: 0>}
#
# Episode: 74, Reward: -116.81675910949707
# info:  {'total_reward': -116.81675910949707, 'total_profit': 0.9509479156930787, 'position': <Positions.Short: 0>}
#
# Episode: 75, Reward: 216.48645401000977
# info:  {'total_reward': 216.48645401000977, 'total_profit': 0.9690344911066392, 'position': <Positions.Long: 1>}
#
# Episode: 76, Reward: -278.49674224853516
# info:  {'total_reward': -278.49674224853516, 'total_profit': 0.9428010674351215, 'position': <Positions.Short: 0>}
#
# Episode: 77, Reward: -114.29190635681152
# info:  {'total_reward': -114.29190635681152, 'total_profit': 0.9544590282309376, 'position': <Positions.Short: 0>}
#
# Episode: 78, Reward: -115.11802673339844
# info:  {'total_reward': -115.11802673339844, 'total_profit': 0.9558796258370341, 'position': <Positions.Long: 1>}
#
# Episode: 79, Reward: -250.58627128601074
# info:  {'total_reward': -250.58627128601074, 'total_profit': 0.9467358302174657, 'position': <Positions.Short: 0>}
#
# Episode: 80, Reward: -625.4839897155762
# info:  {'total_reward': -625.4839897155762, 'total_profit': 0.9316931225313667, 'position': <Positions.Long: 1>}
#
# Episode: 81, Reward: -23.915767669677734
# info:  {'total_reward': -23.915767669677734, 'total_profit': 0.9607206293453263, 'position': <Positions.Short: 0>}
#
# Episode: 82, Reward: -687.5050067901611
# info:  {'total_reward': -687.5050067901611, 'total_profit': 0.9303396155830874, 'position': <Positions.Long: 1>}
#
# Episode: 83, Reward: -446.7010498046875
# info:  {'total_reward': -446.7010498046875, 'total_profit': 0.9384002374554247, 'position': <Positions.Long: 1>}
#
# Episode: 84, Reward: 640.2909755706787
# info:  {'total_reward': 640.2909755706787, 'total_profit': 0.9860542695666394, 'position': <Positions.Short: 0>}
#
# Episode: 85, Reward: -54.50010299682617
# info:  {'total_reward': -54.50010299682617, 'total_profit': 0.9603164722159446, 'position': <Positions.Long: 1>}
#
# Episode: 86, Reward: -600.8040904998779
# info:  {'total_reward': -600.8040904998779, 'total_profit': 0.9306940342230464, 'position': <Positions.Short: 0>}
#
# Episode: 87, Reward: -152.89783477783203
# info:  {'total_reward': -152.89783477783203, 'total_profit': 0.9545008172016827, 'position': <Positions.Long: 1>}
#
# Episode: 88, Reward: -297.8944778442383
# info:  {'total_reward': -297.8944778442383, 'total_profit': 0.9467733348342174, 'position': <Positions.Long: 1>}
#
# Episode: 89, Reward: -324.0847587585449
# info:  {'total_reward': -324.0847587585449, 'total_profit': 0.9457473563650541, 'position': <Positions.Long: 1>}
#
# Episode: 90, Reward: -223.8023281097412
# info:  {'total_reward': -223.8023281097412, 'total_profit': 0.9487515395874765, 'position': <Positions.Short: 0>}
#
# Episode: 91, Reward: -26.487112045288086
# info:  {'total_reward': -26.487112045288086, 'total_profit': 0.9596696942466838, 'position': <Positions.Long: 1>}
#
# Episode: 92, Reward: 66.08366966247559
# info:  {'total_reward': 66.08366966247559, 'total_profit': 0.9656420496185981, 'position': <Positions.Long: 1>}
#
# Episode: 93, Reward: -151.59964561462402
# info:  {'total_reward': -151.59964561462402, 'total_profit': 0.9496092824863285, 'position': <Positions.Short: 0>}
#
# Episode: 94, Reward: -6.90460205078125
# info:  {'total_reward': -6.90460205078125, 'total_profit': 0.9601914352192694, 'position': <Positions.Short: 0>}
#
# Episode: 95, Reward: 381.5138339996338
# info:  {'total_reward': 381.5138339996338, 'total_profit': 0.9769426741414932, 'position': <Positions.Long: 1>}
#
# Episode: 96, Reward: -107.91659355163574
# info:  {'total_reward': -107.91659355163574, 'total_profit': 0.9502280209234918, 'position': <Positions.Short: 0>}
#
# Episode: 97, Reward: 142.70305633544922
# info:  {'total_reward': 142.70305633544922, 'total_profit': 0.9646652847732947, 'position': <Positions.Long: 1>}
#
# Episode: 98, Reward: 263.81373405456543
# info:  {'total_reward': 263.81373405456543, 'total_profit': 0.9727168090990396, 'position': <Positions.Long: 1>}
#
# Episode: 99, Reward: -306.50973320007324
# info:  {'total_reward': -306.50973320007324, 'total_profit': 0.9435806392927942, 'position': <Positions.Short: 0>}
#
# Episode: 100, Reward: 35.59708595275879
# info:  {'total_reward': 35.59708595275879, 'total_profit': 0.9608139804418044, 'position': <Positions.Short: 0>}
#
# Episode: 101, Reward: -420.0589656829834
# info:  {'total_reward': -420.0589656829834, 'total_profit': 0.9420425174602487, 'position': <Positions.Long: 1>}
#
# Episode: 102, Reward: 8.289813995361328
# info:  {'total_reward': 8.289813995361328, 'total_profit': 0.9600497578642649, 'position': <Positions.Short: 0>}
#
# Episode: 103, Reward: 41.31317138671875
# info:  {'total_reward': 41.31317138671875, 'total_profit': 0.9616464175635019, 'position': <Positions.Short: 0>}
#
# Episode: 104, Reward: -245.09668350219727
# info:  {'total_reward': -245.09668350219727, 'total_profit': 0.9484405146558689, 'position': <Positions.Short: 0>}
#
# Episode: 105, Reward: -698.695182800293
# info:  {'total_reward': -698.695182800293, 'total_profit': 0.9301252259912878, 'position': <Positions.Short: 0>}
#
# Episode: 106, Reward: -486.1140251159668
# info:  {'total_reward': -486.1140251159668, 'total_profit': 0.9393750683836432, 'position': <Positions.Long: 1>}
#
# Episode: 107, Reward: 301.1202812194824
# info:  {'total_reward': 301.1202812194824, 'total_profit': 0.9698875571993761, 'position': <Positions.Long: 1>}
# Episode: 108, Reward: -25.103092193603516
# info:  {'total_reward': -25.103092193603516, 'total_profit': 0.9568178816568007, 'position': <Positions.Short: 0>}
#
# Episode: 109, Reward: 248.11029434204102
# info:  {'total_reward': 248.11029434204102, 'total_profit': 0.970580551068213, 'position': <Positions.Long: 1>}
#
# Episode: 110, Reward: -137.09783554077148
# info:  {'total_reward': -137.09783554077148, 'total_profit': 0.9528115270078751, 'position': <Positions.Long: 1>}
#
# Episode: 111, Reward: 234.89952087402344
# info:  {'total_reward': 234.89952087402344, 'total_profit': 0.9739205117818599, 'position': <Positions.Short: 0>}
#
# Episode: 112, Reward: 128.5099983215332
# info:  {'total_reward': 128.5099983215332, 'total_profit': 0.9661315301959953, 'position': <Positions.Long: 1>}
#
# Episode: 113, Reward: -334.31291580200195
# info:  {'total_reward': -334.31291580200195, 'total_profit': 0.9439410465882039, 'position': <Positions.Long: 1>}
#
# Episode: 114, Reward: 380.91421127319336
# info:  {'total_reward': 380.91421127319336, 'total_profit': 0.9788629310723032, 'position': <Positions.Short: 0>}
#
# Episode: 115, Reward: -173.30408096313477
# info:  {'total_reward': -173.30408096313477, 'total_profit': 0.9514819746495972, 'position': <Positions.Short: 0>}
#
# Episode: 116, Reward: -6.586313247680664
# info:  {'total_reward': -6.586313247680664, 'total_profit': 0.9573363853862705, 'position': <Positions.Short: 0>}
#
# Episode: 117, Reward: -431.1215877532959
# info:  {'total_reward': -431.1215877532959, 'total_profit': 0.9403244352258848, 'position': <Positions.Short: 0>}
#
# Episode: 118, Reward: 171.8902587890625
# info:  {'total_reward': 171.8902587890625, 'total_profit': 0.966338979704371, 'position': <Positions.Long: 1>}
#
# Episode: 119, Reward: -130.49602508544922
# info:  {'total_reward': -130.49602508544922, 'total_profit': 0.9563357125459977, 'position': <Positions.Long: 1>}
#
# Episode: 120, Reward: -17.51542091369629
# info:  {'total_reward': -17.51542091369629, 'total_profit': 0.9620546280936159, 'position': <Positions.Long: 1>}
#
# Episode: 121, Reward: 104.48694229125977
# info:  {'total_reward': 104.48694229125977, 'total_profit': 0.9636207103693459, 'position': <Positions.Long: 1>}
#
# Episode: 122, Reward: 197.28660583496094
# info:  {'total_reward': 197.28660583496094, 'total_profit': 0.9676081321341875, 'position': <Positions.Long: 1>}
#
# Episode: 123, Reward: 107.49101638793945
# info:  {'total_reward': 107.49101638793945, 'total_profit': 0.9632870678722274, 'position': <Positions.Short: 0>}
#
# Episode: 124, Reward: -163.10453414916992
# info:  {'total_reward': -163.10453414916992, 'total_profit': 0.9542576704590627, 'position': <Positions.Short: 0>}
#
# Episode: 125, Reward: 270.71237564086914
# info:  {'total_reward': 270.71237564086914, 'total_profit': 0.9717838400661593, 'position': <Positions.Long: 1>}
#
# Episode: 126, Reward: -147.68600463867188
# info:  {'total_reward': -147.68600463867188, 'total_profit': 0.9548982158618006, 'position': <Positions.Short: 0>}
#
# Episode: 127, Reward: 324.6784210205078
# info:  {'total_reward': 324.6784210205078, 'total_profit': 0.9759914769484296, 'position': <Positions.Long: 1>}
#
# Episode: 128, Reward: 314.5182132720947
# info:  {'total_reward': 314.5182132720947, 'total_profit': 0.9770271357484361, 'position': <Positions.Long: 1>}
#
# Episode: 129, Reward: 296.095609664917
# info:  {'total_reward': 296.095609664917, 'total_profit': 0.9730462628139351, 'position': <Positions.Short: 0>}
#
# Episode: 130, Reward: 50.81772804260254
# info:  {'total_reward': 50.81772804260254, 'total_profit': 0.9595348597435329, 'position': <Positions.Short: 0>}
#
# Episode: 131, Reward: -25.10547637939453
# info:  {'total_reward': -25.10547637939453, 'total_profit': 0.9588911177533259, 'position': <Positions.Long: 1>}
#
# Episode: 132, Reward: -17.3032283782959
# info:  {'total_reward': -17.3032283782959, 'total_profit': 0.9604937572989337, 'position': <Positions.Long: 1>}
#
# Episode: 133, Reward: 534.893274307251
# info:  {'total_reward': 534.893274307251, 'total_profit': 0.987962532506551, 'position': <Positions.Long: 1>}
#
# Episode: 134, Reward: 492.6943778991699
# info:  {'total_reward': 492.6943778991699, 'total_profit': 0.9805730041682552, 'position': <Positions.Long: 1>}
#
# Episode: 135, Reward: -146.90756797790527
# info:  {'total_reward': -146.90756797790527, 'total_profit': 0.9540897641152033, 'position': <Positions.Long: 1>}
#
# Episode: 136, Reward: -325.70838928222656
# info:  {'total_reward': -325.70838928222656, 'total_profit': 0.9440744590011595, 'position': <Positions.Short: 0>}
#
# Episode: 137, Reward: 219.50960159301758
# info:  {'total_reward': 219.50960159301758, 'total_profit': 0.9680486174557209, 'position': <Positions.Short: 0>}
#
# Episode: 138, Reward: -192.3084259033203
# info:  {'total_reward': -192.3084259033203, 'total_profit': 0.9514232711491201, 'position': <Positions.Long: 1>}
#
# Episode: 139, Reward: 240.10419845581055
# info:  {'total_reward': 240.10419845581055, 'total_profit': 0.9689364771005566, 'position': <Positions.Long: 1>}
#
# Episode: 140, Reward: -127.31194496154785
# info:  {'total_reward': -127.31194496154785, 'total_profit': 0.951816326151725, 'position': <Positions.Short: 0>}
#
# Episode: 141, Reward: -101.50432586669922
# info:  {'total_reward': -101.50432586669922, 'total_profit': 0.9536497663843904, 'position': <Positions.Short: 0>}
#
# Episode: 142, Reward: 14.897584915161133
# info:  {'total_reward': 14.897584915161133, 'total_profit': 0.9586292838126788, 'position': <Positions.Short: 0>}
#
# Episode: 143, Reward: 173.69985580444336
# info:  {'total_reward': 173.69985580444336, 'total_profit': 0.9682734449808971, 'position': <Positions.Long: 1>}
#
# Episode: 144, Reward: -166.3076877593994
# info:  {'total_reward': -166.3076877593994, 'total_profit': 0.9541331967903166, 'position': <Positions.Long: 1>}
#
# Episode: 145, Reward: 418.4854030609131
# info:  {'total_reward': 418.4854030609131, 'total_profit': 0.9761547907314694, 'position': <Positions.Short: 0>}
#
# Episode: 146, Reward: 89.71214294433594
# info:  {'total_reward': 89.71214294433594, 'total_profit': 0.9621214057828406, 'position': <Positions.Long: 1>}
#
# Episode: 147, Reward: 212.8899097442627
# info:  {'total_reward': 212.8899097442627, 'total_profit': 0.9668729329888589, 'position': <Positions.Long: 1>}
#
# Episode: 148, Reward: 584.099292755127
# info:  {'total_reward': 584.099292755127, 'total_profit': 0.9872524749033303, 'position': <Positions.Short: 0>}
#
# Episode: 149, Reward: -315.81997871398926
# info:  {'total_reward': -315.81997871398926, 'total_profit': 0.9433025315417487, 'position': <Positions.Short: 0>}
#
# Episode: 150, Reward: -161.1006259918213
# info:  {'total_reward': -161.1006259918213, 'total_profit': 0.9541223857062554, 'position': <Positions.Short: 0>}
#
# Episode: 151, Reward: 302.89292335510254
# info:  {'total_reward': 302.89292335510254, 'total_profit': 0.971279181733758, 'position': <Positions.Short: 0>}
#
# Episode: 152, Reward: -0.5125999450683594
# info:  {'total_reward': -0.5125999450683594, 'total_profit': 0.9586190051185328, 'position': <Positions.Short: 0>}
#
# Episode: 153, Reward: 270.3070640563965
# info:  {'total_reward': 270.3070640563965, 'total_profit': 0.9701241674681141, 'position': <Positions.Long: 1>}
#
# Episode: 154, Reward: 91.3095474243164
# info:  {'total_reward': 91.3095474243164, 'total_profit': 0.9624102247750987, 'position': <Positions.Short: 0>}
#
# Episode: 155, Reward: 30.705928802490234
# info:  {'total_reward': 30.705928802490234, 'total_profit': 0.9611359423102233, 'position': <Positions.Short: 0>}
#
# Episode: 156, Reward: -309.1013431549072
# info:  {'total_reward': -309.1013431549072, 'total_profit': 0.9458566998030716, 'position': <Positions.Long: 1>}
#
# Episode: 157, Reward: -1.0943412780761719
# info:  {'total_reward': -1.0943412780761719, 'total_profit': 0.9593478484391096, 'position': <Positions.Short: 0>}
#
# Episode: 158, Reward: -209.30767059326172
# info:  {'total_reward': -209.30767059326172, 'total_profit': 0.9523609431964285, 'position': <Positions.Short: 0>}
#
# Episode: 159, Reward: 97.69678115844727
# info:  {'total_reward': 97.69678115844727, 'total_profit': 0.9618406576434757, 'position': <Positions.Long: 1>}
#
# Episode: 160, Reward: -24.30558204650879
# info:  {'total_reward': -24.30558204650879, 'total_profit': 0.9568023020201586, 'position': <Positions.Short: 0>}
# Episode: 161, Reward: 106.10818862915039
# info:  {'total_reward': 106.10818862915039, 'total_profit': 0.9676567861904711, 'position': <Positions.Short: 0>}
#
# Episode: 162, Reward: 397.20892906188965
# info:  {'total_reward': 397.20892906188965, 'total_profit': 0.9734347053896356, 'position': <Positions.Short: 0>}
#
# Episode: 163, Reward: -212.30816841125488
# info:  {'total_reward': -212.30816841125488, 'total_profit': 0.9539384870045253, 'position': <Positions.Short: 0>}
#
# Episode: 164, Reward: -59.32331085205078
# info:  {'total_reward': -59.32331085205078, 'total_profit': 0.9554947576363391, 'position': <Positions.Long: 1>}
#
# Episode: 165, Reward: -95.39484977722168
# info:  {'total_reward': -95.39484977722168, 'total_profit': 0.9522449652118995, 'position': <Positions.Short: 0>}
#
# Episode: 166, Reward: -340.9159183502197
# info:  {'total_reward': -340.9159183502197, 'total_profit': 0.9419416342592505, 'position': <Positions.Short: 0>}
#
# Episode: 167, Reward: -300.50039291381836
# info:  {'total_reward': -300.50039291381836, 'total_profit': 0.9462419548942564, 'position': <Positions.Short: 0>}
#
# Episode: 168, Reward: 50.913095474243164
# info:  {'total_reward': 50.913095474243164, 'total_profit': 0.9621035487272986, 'position': <Positions.Short: 0>}
#
# Episode: 169, Reward: -131.1028003692627
# info:  {'total_reward': -131.1028003692627, 'total_profit': 0.9534796448199956, 'position': <Positions.Long: 1>}
#
# Episode: 170, Reward: -134.1104507446289
# info:  {'total_reward': -134.1104507446289, 'total_profit': 0.9520437125533974, 'position': <Positions.Short: 0>}
#
# Episode: 171, Reward: 49.90100860595703
# info:  {'total_reward': 49.90100860595703, 'total_profit': 0.9608936415998431, 'position': <Positions.Short: 0>}
#
# Episode: 172, Reward: 210.51645278930664
# info:  {'total_reward': 210.51645278930664, 'total_profit': 0.9676811983258231, 'position': <Positions.Short: 0>}
#
# Episode: 173, Reward: -135.8950138092041
# info:  {'total_reward': -135.8950138092041, 'total_profit': 0.9537807954932195, 'position': <Positions.Short: 0>}
#
# Episode: 174, Reward: 365.68403244018555
# info:  {'total_reward': 365.68403244018555, 'total_profit': 0.9772052791033932, 'position': <Positions.Long: 1>}
#
# Episode: 175, Reward: 142.7149772644043
# info:  {'total_reward': 142.7149772644043, 'total_profit': 0.9669250131795308, 'position': <Positions.Long: 1>}
#
# Episode: 176, Reward: 49.1023063659668
# info:  {'total_reward': 49.1023063659668, 'total_profit': 0.9604794382697397, 'position': <Positions.Short: 0>}
#
# Episode: 177, Reward: 685.8921051025391
# info:  {'total_reward': 685.8921051025391, 'total_profit': 0.9934136532233573, 'position': <Positions.Short: 0>}
#
# Episode: 178, Reward: 406.9030284881592
# info:  {'total_reward': 406.9030284881592, 'total_profit': 0.9813448305022173, 'position': <Positions.Long: 1>}
#
# Episode: 179, Reward: 200.07610321044922
# info:  {'total_reward': 200.07610321044922, 'total_profit': 0.9685167381063382, 'position': <Positions.Short: 0>}
#
# Episode: 180, Reward: 40.09246826171875
# info:  {'total_reward': 40.09246826171875, 'total_profit': 0.9632243343901634, 'position': <Positions.Short: 0>}
#
# Episode: 181, Reward: -96.30680084228516
# info:  {'total_reward': -96.30680084228516, 'total_profit': 0.9559174833962397, 'position': <Positions.Short: 0>}
#
# Episode: 182, Reward: -43.79391670227051
# info:  {'total_reward': -43.79391670227051, 'total_profit': 0.9593049815312344, 'position': <Positions.Long: 1>}
#
# Episode: 183, Reward: -362.08391189575195
# info:  {'total_reward': -362.08391189575195, 'total_profit': 0.941846104897082, 'position': <Positions.Short: 0>}
#
# Episode: 184, Reward: -74.77641105651855
# info:  {'total_reward': -74.77641105651855, 'total_profit': 0.9544807639321533, 'position': <Positions.Short: 0>}
#
# Episode: 185, Reward: 97.09477424621582
# info:  {'total_reward': 97.09477424621582, 'total_profit': 0.9673453418842667, 'position': <Positions.Long: 1>}
#
# Episode: 186, Reward: 241.5025234222412
# info:  {'total_reward': 241.5025234222412, 'total_profit': 0.9746838874224844, 'position': <Positions.Short: 0>}
#
# Episode: 187, Reward: -434.49878692626953
# info:  {'total_reward': -434.49878692626953, 'total_profit': 0.9414260940444137, 'position': <Positions.Long: 1>}
#
# Episode: 188, Reward: 94.00606155395508
# info:  {'total_reward': 94.00606155395508, 'total_profit': 0.9645939795667142, 'position': <Positions.Short: 0>}
#
# Episode: 189, Reward: 143.90110969543457
# info:  {'total_reward': 143.90110969543457, 'total_profit': 0.9664205558840828, 'position': <Positions.Long: 1>}
#
# Episode: 190, Reward: -268.08857917785645
# info:  {'total_reward': -268.08857917785645, 'total_profit': 0.9453189782637186, 'position': <Positions.Short: 0>}
#
# Episode: 191, Reward: 236.48977279663086
# info:  {'total_reward': 236.48977279663086, 'total_profit': 0.9712511607735393, 'position': <Positions.Long: 1>}
#
# Episode: 192, Reward: -2.8967857360839844
# info:  {'total_reward': -2.8967857360839844, 'total_profit': 0.9592530881570644, 'position': <Positions.Short: 0>}
#
# Episode: 193, Reward: 261.2733840942383
# info:  {'total_reward': 261.2733840942383, 'total_profit': 0.9732775206424169, 'position': <Positions.Long: 1>}
#
# Episode: 194, Reward: -96.11368179321289
# info:  {'total_reward': -96.11368179321289, 'total_profit': 0.9574452349817685, 'position': <Positions.Short: 0>}
#
# Episode: 195, Reward: 69.11754608154297
# info:  {'total_reward': 69.11754608154297, 'total_profit': 0.9611170123215586, 'position': <Positions.Long: 1>}
#
# Episode: 196, Reward: -266.30163192749023
# info:  {'total_reward': -266.30163192749023, 'total_profit': 0.9494715321623222, 'position': <Positions.Short: 0>}
#
# Episode: 197, Reward: -273.11086654663086
# info:  {'total_reward': -273.11086654663086, 'total_profit': 0.946897187489764, 'position': <Positions.Long: 1>}
#
# Episode: 198, Reward: -54.912567138671875
# info:  {'total_reward': -54.912567138671875, 'total_profit': 0.9559708316086948, 'position': <Positions.Long: 1>}
#
# Episode: 199, Reward: -326.51662826538086
# info:  {'total_reward': -326.51662826538086, 'total_profit': 0.943926643675387, 'position': <Positions.Long: 1>}
#
# Episode: 200, Reward: -206.68506622314453
# info:  {'total_reward': -206.68506622314453, 'total_profit': 0.9496578521837762, 'position': <Positions.Short: 0>}
#
# Episode: 201, Reward: -331.27427101135254
# info:  {'total_reward': -331.27427101135254, 'total_profit': 0.9443585910026924, 'position': <Positions.Short: 0>}
#
# Episode: 202, Reward: 181.7035675048828
# info:  {'total_reward': 181.7035675048828, 'total_profit': 0.9700632045452265, 'position': <Positions.Long: 1>}
#
# Episode: 203, Reward: 133.39638710021973
# info:  {'total_reward': 133.39638710021973, 'total_profit': 0.9637651868753376, 'position': <Positions.Short: 0>}
#
# Episode: 204, Reward: -147.22704887390137
# info:  {'total_reward': -147.22704887390137, 'total_profit': 0.9521817551779149, 'position': <Positions.Short: 0>}
#
# Episode: 205, Reward: 221.30846977233887
# info:  {'total_reward': 221.30846977233887, 'total_profit': 0.97006214389422, 'position': <Positions.Short: 0>}
#
# Episode: 206, Reward: -290.29011726379395
# info:  {'total_reward': -290.29011726379395, 'total_profit': 0.9465584209868471, 'position': <Positions.Short: 0>}
#
# Episode: 207, Reward: -18.310546875
# info:  {'total_reward': -18.310546875, 'total_profit': 0.9624440783320988, 'position': <Positions.Long: 1>}
#
# Episode: 208, Reward: -603.5065650939941
# info:  {'total_reward': -603.5065650939941, 'total_profit': 0.935415438772261, 'position': <Positions.Short: 0>}
#
# Episode: 209, Reward: 259.91320610046387
# info:  {'total_reward': 259.91320610046387, 'total_profit': 0.9690540481902201, 'position': <Positions.Short: 0>}
#
# Episode: 210, Reward: 233.3080768585205
# info:  {'total_reward': 233.3080768585205, 'total_profit': 0.9741694252281368, 'position': <Positions.Long: 1>}
#
# Episode: 211, Reward: -386.584997177124
# info:  {'total_reward': -386.584997177124, 'total_profit': 0.9430398214009187, 'position': <Positions.Short: 0>}
#
# Episode: 212, Reward: -37.288665771484375
# info:  {'total_reward': -37.288665771484375, 'total_profit': 0.9603179254681364, 'position': <Positions.Short: 0>}
#
# Episode: 213, Reward: 107.11789131164551
# info:  {'total_reward': 107.11789131164551, 'total_profit': 0.9612239400165871, 'position': <Positions.Short: 0>}
# Episode: 214, Reward: -131.49261474609375
# info:  {'total_reward': -131.49261474609375, 'total_profit': 0.9532702114897995, 'position': <Positions.Short: 0>}
#
# Episode: 215, Reward: -608.7207794189453
# info:  {'total_reward': -608.7207794189453, 'total_profit': 0.9316905563152768, 'position': <Positions.Long: 1>}
#
# Episode: 216, Reward: -143.88680458068848
# info:  {'total_reward': -143.88680458068848, 'total_profit': 0.9497592196942392, 'position': <Positions.Short: 0>}
#
# Episode: 217, Reward: -318.4974193572998
# info:  {'total_reward': -318.4974193572998, 'total_profit': 0.9455898040133228, 'position': <Positions.Short: 0>}
#
# Episode: 218, Reward: -18.89824867248535
# info:  {'total_reward': -18.89824867248535, 'total_profit': 0.9613478419960609, 'position': <Positions.Long: 1>}
#
# Episode: 219, Reward: 86.49349212646484
# info:  {'total_reward': 86.49349212646484, 'total_profit': 0.9655894166544424, 'position': <Positions.Long: 1>}
#
# Episode: 220, Reward: -608.1032752990723
# info:  {'total_reward': -608.1032752990723, 'total_profit': 0.9360416629308953, 'position': <Positions.Long: 1>}
#
# Episode: 221, Reward: 209.31005477905273
# info:  {'total_reward': 209.31005477905273, 'total_profit': 0.9681410595738205, 'position': <Positions.Long: 1>}
#
# Episode: 222, Reward: -241.90187454223633
# info:  {'total_reward': -241.90187454223633, 'total_profit': 0.948604015648058, 'position': <Positions.Long: 1>}
#
# Episode: 223, Reward: 94.90609169006348
# info:  {'total_reward': 94.90609169006348, 'total_profit': 0.9651384253467051, 'position': <Positions.Short: 0>}
#
# Episode: 224, Reward: 249.31788444519043
# info:  {'total_reward': 249.31788444519043, 'total_profit': 0.9720933156130949, 'position': <Positions.Long: 1>}
#
# Episode: 225, Reward: 156.31437301635742
# info:  {'total_reward': 156.31437301635742, 'total_profit': 0.9700577805653926, 'position': <Positions.Short: 0>}
#
# Episode: 226, Reward: -1.7821788787841797
# info:  {'total_reward': -1.7821788787841797, 'total_profit': 0.9584928097521143, 'position': <Positions.Short: 0>}
#
# Episode: 227, Reward: -5.918741226196289
# info:  {'total_reward': -5.918741226196289, 'total_profit': 0.9594747641384622, 'position': <Positions.Short: 0>}
#
# Episode: 228, Reward: 366.11318588256836
# info:  {'total_reward': 366.11318588256836, 'total_profit': 0.9765604168998911, 'position': <Positions.Short: 0>}
#
# Episode: 229, Reward: 48.71368408203125
# info:  {'total_reward': 48.71368408203125, 'total_profit': 0.9632666664097241, 'position': <Positions.Short: 0>}
#
# Episode: 230, Reward: 114.27044868469238
# info:  {'total_reward': 114.27044868469238, 'total_profit': 0.9647875375864712, 'position': <Positions.Long: 1>}
#
# Episode: 231, Reward: -214.10465240478516
# info:  {'total_reward': -214.10465240478516, 'total_profit': 0.9517139995881859, 'position': <Positions.Long: 1>}
#
# Episode: 232, Reward: 229.39801216125488
# info:  {'total_reward': 229.39801216125488, 'total_profit': 0.9682701049348793, 'position': <Positions.Short: 0>}
#
# Episode: 233, Reward: -371.08778953552246
# info:  {'total_reward': -371.08778953552246, 'total_profit': 0.9412616095526523, 'position': <Positions.Short: 0>}
#
# Episode: 234, Reward: -260.30540466308594
# info:  {'total_reward': -260.30540466308594, 'total_profit': 0.948673113016834, 'position': <Positions.Long: 1>}
#
# Episode: 235, Reward: -108.49833488464355
# info:  {'total_reward': -108.49833488464355, 'total_profit': 0.9540723468975245, 'position': <Positions.Short: 0>}
#
# Episode: 236, Reward: 195.70231437683105
# info:  {'total_reward': 195.70231437683105, 'total_profit': 0.9703856113896328, 'position': <Positions.Long: 1>}
#
# Episode: 237, Reward: 7.903575897216797
# info:  {'total_reward': 7.903575897216797, 'total_profit': 0.9569767504634942, 'position': <Positions.Short: 0>}
#
# Episode: 238, Reward: -310.4102611541748
# info:  {'total_reward': -310.4102611541748, 'total_profit': 0.9432711927306856, 'position': <Positions.Short: 0>}
#
# Episode: 239, Reward: -600.8744239807129
# info:  {'total_reward': -600.8744239807129, 'total_profit': 0.9340638981641733, 'position': <Positions.Long: 1>}
#
# Episode: 240, Reward: 74.13387298583984
# info:  {'total_reward': 74.13387298583984, 'total_profit': 0.9630814505837885, 'position': <Positions.Long: 1>}
#
# Episode: 241, Reward: 472.50866889953613
# info:  {'total_reward': 472.50866889953613, 'total_profit': 0.9765372081584465, 'position': <Positions.Short: 0>}
#
# Episode: 242, Reward: -420.88866233825684
# info:  {'total_reward': -420.88866233825684, 'total_profit': 0.9414866105851468, 'position': <Positions.Long: 1>}
#
# Episode: 243, Reward: -19.510984420776367
# info:  {'total_reward': -19.510984420776367, 'total_profit': 0.9565926977011446, 'position': <Positions.Short: 0>}
#
# Episode: 244, Reward: 133.8803768157959
# info:  {'total_reward': 133.8803768157959, 'total_profit': 0.9641579291943189, 'position': <Positions.Short: 0>}
#
# Episode: 245, Reward: 90.48223495483398
# info:  {'total_reward': 90.48223495483398, 'total_profit': 0.9614493401941369, 'position': <Positions.Short: 0>}
#
# Episode: 246, Reward: -147.08995819091797
# info:  {'total_reward': -147.08995819091797, 'total_profit': 0.9532326929202739, 'position': <Positions.Short: 0>}
#
# Episode: 247, Reward: -224.32923316955566
# info:  {'total_reward': -224.32923316955566, 'total_profit': 0.9514427979021127, 'position': <Positions.Short: 0>}
#
# Episode: 248, Reward: 291.1114692687988
# info:  {'total_reward': 291.1114692687988, 'total_profit': 0.9742521862217781, 'position': <Positions.Long: 1>}
#
# Episode: 249, Reward: 193.71747970581055
# info:  {'total_reward': 193.71747970581055, 'total_profit': 0.9670250554074838, 'position': <Positions.Short: 0>}
#
# Episode: 250, Reward: -79.29563522338867
# info:  {'total_reward': -79.29563522338867, 'total_profit': 0.9584490271639281, 'position': <Positions.Short: 0>}
#
# Episode: 251, Reward: -420.302152633667
# info:  {'total_reward': -420.302152633667, 'total_profit': 0.9396191166737727, 'position': <Positions.Short: 0>}
#
# Episode: 252, Reward: -207.89861679077148
# info:  {'total_reward': -207.89861679077148, 'total_profit': 0.9531058594806827, 'position': <Positions.Long: 1>}
#
# Episode: 253, Reward: -65.49596786499023
# info:  {'total_reward': -65.49596786499023, 'total_profit': 0.9541109786914914, 'position': <Positions.Long: 1>}
#
# Episode: 254, Reward: -530.6994915008545
# info:  {'total_reward': -530.6994915008545, 'total_profit': 0.9357881744413863, 'position': <Positions.Short: 0>}
#
# Episode: 255, Reward: -600.8875370025635
# info:  {'total_reward': -600.8875370025635, 'total_profit': 0.9294057231296002, 'position': <Positions.Short: 0>}
#
# Episode: 256, Reward: -153.10168266296387
# info:  {'total_reward': -153.10168266296387, 'total_profit': 0.9539232959940751, 'position': <Positions.Long: 1>}
#
# Episode: 257, Reward: 430.1023483276367
# info:  {'total_reward': 430.1023483276367, 'total_profit': 0.9810138412842561, 'position': <Positions.Short: 0>}
#
# Episode: 258, Reward: -58.50076675415039
# info:  {'total_reward': -58.50076675415039, 'total_profit': 0.959286954680201, 'position': <Positions.Short: 0>}
#
# Episode: 259, Reward: -86.08102798461914
# info:  {'total_reward': -86.08102798461914, 'total_profit': 0.9557432200658965, 'position': <Positions.Short: 0>}
#
# Episode: 260, Reward: -97.49174118041992
# info:  {'total_reward': -97.49174118041992, 'total_profit': 0.9568433833331271, 'position': <Positions.Long: 1>}
#
# Episode: 261, Reward: -95.1087474822998
# info:  {'total_reward': -95.1087474822998, 'total_profit': 0.9528205497256297, 'position': <Positions.Short: 0>}
#
# Episode: 262, Reward: 293.7185764312744
# info:  {'total_reward': 293.7185764312744, 'total_profit': 0.9750182964950358, 'position': <Positions.Short: 0>}
#
# Episode: 263, Reward: -112.90311813354492
# info:  {'total_reward': -112.90311813354492, 'total_profit': 0.9545252979396067, 'position': <Positions.Long: 1>}
#
# Episode: 264, Reward: -73.8060474395752
# info:  {'total_reward': -73.8060474395752, 'total_profit': 0.9566930554730263, 'position': <Positions.Short: 0>}
#
# Episode: 265, Reward: -82.70263671875
# info:  {'total_reward': -82.70263671875, 'total_profit': 0.9543201879823315, 'position': <Positions.Long: 1>}
#
# Episode: 266, Reward: -187.29686737060547
# info:  {'total_reward': -187.29686737060547, 'total_profit': 0.9537405289781057, 'position': <Positions.Long: 1>}
# Episode: 267, Reward: -450.87695121765137
# info:  {'total_reward': -450.87695121765137, 'total_profit': 0.9368587998904923, 'position': <Positions.Short: 0>}
#
# Episode: 268, Reward: 220.27850151062012
# info:  {'total_reward': 220.27850151062012, 'total_profit': 0.9709945824977978, 'position': <Positions.Long: 1>}
#
# Episode: 269, Reward: -478.6956310272217
# info:  {'total_reward': -478.6956310272217, 'total_profit': 0.93833144178393, 'position': <Positions.Short: 0>}
#
# Episode: 270, Reward: -138.08727264404297
# info:  {'total_reward': -138.08727264404297, 'total_profit': 0.9558979442790017, 'position': <Positions.Long: 1>}
#
# Episode: 271, Reward: 76.10321044921875
# info:  {'total_reward': 76.10321044921875, 'total_profit': 0.966149726956486, 'position': <Positions.Long: 1>}
#
# Episode: 272, Reward: -221.70066833496094
# info:  {'total_reward': -221.70066833496094, 'total_profit': 0.9511785353627958, 'position': <Positions.Short: 0>}
#
# Episode: 273, Reward: 248.08049201965332
# info:  {'total_reward': 248.08049201965332, 'total_profit': 0.9709714117981821, 'position': <Positions.Long: 1>}
#
# Episode: 274, Reward: 298.7182140350342
# info:  {'total_reward': 298.7182140350342, 'total_profit': 0.9727377857560521, 'position': <Positions.Long: 1>}
#
# Episode: 275, Reward: -368.70598793029785
# info:  {'total_reward': -368.70598793029785, 'total_profit': 0.9430431297108643, 'position': <Positions.Short: 0>}
#
# Episode: 276, Reward: -117.66910552978516
# info:  {'total_reward': -117.66910552978516, 'total_profit': 0.9543434282768399, 'position': <Positions.Long: 1>}
#
# Episode: 277, Reward: -97.10311889648438
# info:  {'total_reward': -97.10311889648438, 'total_profit': 0.9564546706843422, 'position': <Positions.Short: 0>}
#
# Episode: 278, Reward: -548.6869812011719
# info:  {'total_reward': -548.6869812011719, 'total_profit': 0.9340103963860318, 'position': <Positions.Short: 0>}
#
# Episode: 279, Reward: -60.49633026123047
# info:  {'total_reward': -60.49633026123047, 'total_profit': 0.9576006281079391, 'position': <Positions.Long: 1>}
#
# Episode: 280, Reward: 29.69503402709961
# info:  {'total_reward': 29.69503402709961, 'total_profit': 0.9612759687135916, 'position': <Positions.Short: 0>}
#
# Episode: 281, Reward: 38.88726234436035
# info:  {'total_reward': 38.88726234436035, 'total_profit': 0.9612638574047866, 'position': <Positions.Short: 0>}
#
# Episode: 282, Reward: -201.86662673950195
# info:  {'total_reward': -201.86662673950195, 'total_profit': 0.9515560260338666, 'position': <Positions.Short: 0>}
#
# Episode: 283, Reward: -586.707592010498
# info:  {'total_reward': -586.707592010498, 'total_profit': 0.9317091829269691, 'position': <Positions.Long: 1>}
#
# Episode: 284, Reward: -18.296241760253906
# info:  {'total_reward': -18.296241760253906, 'total_profit': 0.9602397512683256, 'position': <Positions.Short: 0>}
#
# Episode: 285, Reward: -494.7948455810547
# info:  {'total_reward': -494.7948455810547, 'total_profit': 0.9381112869843053, 'position': <Positions.Short: 0>}
#
# Episode: 286, Reward: -296.7095375061035
# info:  {'total_reward': -296.7095375061035, 'total_profit': 0.9460450192496879, 'position': <Positions.Long: 1>}
#
# Episode: 287, Reward: -496.71173095703125
# info:  {'total_reward': -496.71173095703125, 'total_profit': 0.9395337804993051, 'position': <Positions.Short: 0>}
#
# Episode: 288, Reward: -73.98724555969238
# info:  {'total_reward': -73.98724555969238, 'total_profit': 0.9584898800629064, 'position': <Positions.Short: 0>}
#
# Episode: 289, Reward: -35.686492919921875
# info:  {'total_reward': -35.686492919921875, 'total_profit': 0.9607739045026767, 'position': <Positions.Long: 1>}
#
# Episode: 290, Reward: -122.09773063659668
# info:  {'total_reward': -122.09773063659668, 'total_profit': 0.9557733937569454, 'position': <Positions.Short: 0>}
#
# Episode: 291, Reward: 0.2980232238769531
# info:  {'total_reward': 0.2980232238769531, 'total_profit': 0.9600376426733229, 'position': <Positions.Short: 0>}
#
# Episode: 292, Reward: 68.68720054626465
# info:  {'total_reward': 68.68720054626465, 'total_profit': 0.9685485505922988, 'position': <Positions.Long: 1>}
#
# Episode: 293, Reward: 304.0897846221924
# info:  {'total_reward': 304.0897846221924, 'total_profit': 0.9789404848567715, 'position': <Positions.Long: 1>}
#
# Episode: 294, Reward: 193.30263137817383
# info:  {'total_reward': 193.30263137817383, 'total_profit': 0.9699573414150533, 'position': <Positions.Long: 1>}
#
# Episode: 295, Reward: -131.10756874084473
# info:  {'total_reward': -131.10756874084473, 'total_profit': 0.9514539096979512, 'position': <Positions.Short: 0>}
#
# Episode: 296, Reward: 592.491626739502
# info:  {'total_reward': 592.491626739502, 'total_profit': 0.9882976257513474, 'position': <Positions.Short: 0>}
#
# Episode: 297, Reward: 355.1149368286133
# info:  {'total_reward': 355.1149368286133, 'total_profit': 0.9771007608660899, 'position': <Positions.Short: 0>}
#
# Episode: 298, Reward: 294.7056293487549
# info:  {'total_reward': 294.7056293487549, 'total_profit': 0.9714719137091766, 'position': <Positions.Short: 0>}
#
# Episode: 299, Reward: 137.12167739868164
# info:  {'total_reward': 137.12167739868164, 'total_profit': 0.9627683722363178, 'position': <Positions.Short: 0>}
#
# Episode: 300, Reward: 377.2878646850586
# info:  {'total_reward': 377.2878646850586, 'total_profit': 0.9785902729675185, 'position': <Positions.Short: 0>}
